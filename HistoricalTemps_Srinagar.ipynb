# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt; from csv import reader; import pandas as pd;

# %%
df=pd.read_csv("Temp_data.csv", delimiter=",") # This data was downloaded from http://berkeleyearth.lbl.gov/stations/155633 
#For Srinagar Kashmir

# %%
df.columns
# Out:
# Index([u'Year', u'Month', u'Raw_Temperature', u'Anomaly_Raw', u'QC_failed',
#        u'Continuity_Breaks', u'Adjusted_Temperature', u'Anomaly_Adjusted',
#        u'Regional_Expectation_Temperature ', u'Anomaly_Expected'],
#       dtype='object')

# %%
df
# Out:
#       Year  Month  Raw_Temperature  Anomaly_Raw  QC_failed  Continuity_Breaks  \
# 0     1890     10              NaN          NaN        NaN                NaN
# 1     1890     11              NaN          NaN        NaN                NaN
# 2     1890     12              NaN          NaN        NaN                NaN
# 3     1891      1              NaN          NaN        NaN                NaN
# 4     1891      2              NaN          NaN        NaN                NaN
# 5     1891      3              NaN          NaN        NaN                NaN
# 6     1891      4              NaN          NaN        NaN                NaN
# 7     1891      5              NaN          NaN        NaN                NaN
# 8     1891      6              NaN          NaN        NaN                NaN
# 9     1891      7              NaN          NaN        NaN                NaN
# 10    1891      8              NaN          NaN        NaN                NaN
# ...

# %%
plt.scatter(df["Month"], df["Adjusted_Temperature"])

# %%
plt.boxplot(df["Raw_Temperature"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x13357dd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x13367ac8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x13378b70>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x133785f8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x13357ef0>,
#   <matplotlib.lines.Line2D at 0x13367550>]}

# %%
fig, ax = plt.subplots(3)
ax[1].plot(df['Raw_Temperature'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-269-891252ce4b63> in <module>()
#       1 fig, ax = plt.subplots(3)
# ----> 2 ax[1].plt.boxplot(df["Raw_Temperature"])
#
# AttributeError: 'AxesSubplot' object has no attribute 'plt'
